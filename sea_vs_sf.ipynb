# %%
# This is a package in preview.
# You need to pip install azureml-opendatasets in Databricks cluster. https://docs.microsoft.com/en-us/azure/data-explorer/connect-from-databricks#install-the-python-library-on-your-azure-databricks-cluster
from azureml.opendatasets import SeattleSafety

from datetime import datetime
from dateutil import parser


end_date = parser.parse('2016-01-01')
start_date = parser.parse('2015-05-01')
safety = SeattleSafety(start_date=start_date, end_date=end_date)
safety = safety.to_spark_dataframe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f3be167397db> in <module>
#      10 start_date = parser.parse('2015-05-01')
#      11 safety = SeattleSafety(start_date=start_date, end_date=end_date)
# ---> 12 safety = safety.to_spark_dataframe()
#
# /usr/local/lib/python3.6/dist-packages/azureml/opendatasets/accessories/_loggerfactory.py in wrapper(*args, **kwargs)
#     137             with _LoggerFactory.track_activity(logger, func.__name__, activity_type, custom_dimensions) as al:
#     138                 try:
# --> 139                     return func(*args, **kwargs)
#     140                 except Exception as e:
#     141                     al.activity_info['error_message'] = str(e)
#
# /usr/local/lib/python3.6/dist-packages/azureml/opendatasets/accessories/open_dataset_base.py in to_spark_dataframe(self)
#     162             _LoggerFactory.log_event(
#     163                 'to_spark_dataframe_in_worker', **self._log_properties)
# --> 164         return self._to_spark_dataframe()
#     165
#     166     @classmethod
#
# /usr/local/lib/python3.6/dist-packages/azureml/opendatasets/accessories/open_dataset_base.py in _to_spark_dataframe(self)
#     305         return self._blob_accessor.get_spark_dataframe(
#     306             self.cols,
# --> 307             **self._kwargs
#     308         )
#     309
#
# /usr/local/lib/python3.6/dist-packages/azureml/opendatasets/dataaccess/_blob_accessor.py in get_spark_dataframe(self, cols, **kwargs)
#     296         cols = self._get_cols(cols)
#     297         targets_dataframe = self.get_file_dataflow(
# --> 298             **kwargs).to_pandas_dataframe()
#     299         if targets_dataframe.empty:
#     300             return None
#
# /usr/local/lib/python3.6/dist-packages/azureml/opendatasets/dataaccess/_blob_accessor.py in get_file_dataflow(self, **kwargs)
#     158     def get_file_dataflow(self, **kwargs) -> dprep.Dataflow:
#     159         self._check_dataprep()
# --> 160         dflow = dprep.Dataflow.get_files(self.get_urls(**kwargs))
#     161         dflow = self._filter_file_dataflow(dflow, **kwargs)
#     162         #  skip for now and wait for DataPrep Official release to studio
#
# /usr/local/lib/python3.6/dist-packages/azureml/dataprep/api/dataflow.py in get_files(path)
#    2356         :return: A new Dataflow.
#    2357         """
# -> 2358         return Dataflow._path_to_get_files_block(path)
#    2359
#    2360     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/azureml/dataprep/api/dataflow.py in _path_to_get_files_block(path, archive_options)
#    2429
#    2430         datasource = path if isinstance(path, FileDataSource) else FileDataSource.datasource_from_str(path)
# -> 2431         return Dataflow._get_files(datasource, archive_options)
#    2432
#    2433     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/azureml/dataprep/api/dataflow.py in _get_files(path, archive_options)
#    2439         :return: A new Dataflow.
#    2440         """
# -> 2441         df = Dataflow(get_engine_api())
#    2442         args = {
#    2443             'path': path.underlying_value
#
# /usr/local/lib/python3.6/dist-packages/azureml/dataprep/api/engineapi/api.py in get_engine_api()
#      17     global _engine_api
#      18     if not _engine_api:
# ---> 19         _engine_api = EngineAPI()
#      20
#      21         from .._dataset_resolver import register_dataset_resolver
#
# /usr/local/lib/python3.6/dist-packages/azureml/dataprep/api/engineapi/api.py in __init__(self)
#      66                     pass
#      67
# ---> 68         self._message_channel = launch_engine()
#      69         connect_to_requests_channel()
#      70
#
# /usr/local/lib/python3.6/dist-packages/azureml/dataprep/api/engineapi/engine.py in launch_engine()
#     331     engine_path = _get_engine_path()
#     332     try:
# --> 333         dependencies_path = runtime.ensure_dependencies()
#     334     except Exception as e:
#     335         _LoggerFactory.trace(log, 'Failed to ensure dependencies' + str(e))
#
# /usr/local/lib/python3.6/dist-packages/dotnetcore2/runtime.py in ensure_dependencies()
#     283             return success
#     284
# --> 285         if not attempt_get_deps():
#     286             # Failed accessing blob, likely an interrupted connection. Try again once more.
#     287             if not attempt_get_deps():
#
# /usr/local/lib/python3.6/dist-packages/dotnetcore2/runtime.py in attempt_get_deps()
#     269             success = False
#     270             try:
# --> 271                 blob_deps_to_file()
#     272                 success = True
#     273             except HTTPError as e:
#
# /usr/local/lib/python3.6/dist-packages/dotnetcore2/runtime.py in blob_deps_to_file()
#     263             blob = request.urlopen(deps_url, context=ssl_context)
#     264             with open(deps_tar_path, 'wb') as f:
# --> 265                 f.write(blob.read())
#     266                 blob.close()
#     267
#
# /usr/lib/python3.6/http/client.py in read(self, amt)
#     474             else:
#     475                 try:
# --> 476                     s = self._safe_read(self.length)
#     477                 except IncompleteRead:
#     478                     self._close_conn()
#
# /usr/lib/python3.6/http/client.py in _safe_read(self, amt)
#     624         s = []
#     625         while amt > 0:
# --> 626             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     627             if not chunk:
#     628                 raise IncompleteRead(b''.join(s), amt)
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
display(safety.limit(5))
# Out:
# Error: Pip module Unable to parse debugpy output, please log an issue with https://github.com/microsoft/vscode-jupyter is required for debugging cells. You will need to install it to debug cells.
# at b.parseConnectInfo (/root/.vscode-server/extensions/ms-toolsai.jupyter-2021.5.745244803/out/client/extension.js:49:478177)
# at b.connectToLocal (/root/.vscode-server/extensions/ms-toolsai.jupyter-2021.5.745244803/out/client/extension.js:49:478704)
# at async b.connect (/root/.vscode-server/extensions/ms-toolsai.jupyter-2021.5.745244803/out/client/extension.js:49:476581)
# at async b.startDebugSession (/root/.vscode-server/extensions/ms-toolsai.jupyter-2021.5.745244803/out/client/extension.js:49:475728)
# at async T.submitCode (/root/.vscode-server/extensions/ms-toolsai.jupyter-2021.5.745244803/out/client/extension.js:32:663261)
# at async T.handleRunByLine (/root/.vscode-server/extensions/ms-toolsai.jupyter-2021.5.745244803/out/client/extension.js:32:651205)
